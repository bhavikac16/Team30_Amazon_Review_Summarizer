# %%
import os
import time
import pickle
import re
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import undetected_chromedriver as uc

# ---------- Setup Chrome ----------
options = uc.ChromeOptions()
options.add_argument('--start-maximized')
driver = uc.Chrome(options=options)
time.sleep(2)

# ---------- Load Cookies ----------
cookies_path = "cookies/amazon_cookies.pkl"
driver.get("https://www.amazon.in/")
time.sleep(3)

if os.path.exists(cookies_path):
    with open(cookies_path, "rb") as f:
        cookies = pickle.load(f)
        for cookie in cookies:
            if 'sameSite' in cookie:
                cookie['sameSite'] = 'Strict'
            try:
                driver.add_cookie(cookie)
            except:
                continue

driver.refresh()
time.sleep(3)

# ---------- Helpers ----------
def parse_review_count(text):
    text = text.replace(",", "").lower().strip()
    try:
        if "k" in text:
            return int(float(text.replace("k", "")) * 1000)
        elif "m" in text:
            return int(float(text.replace("m", "")) * 1_000_000)
        return int(text)
    except:
        return 0

def extract_asin(url):
    match = re.search(r'/product-reviews/([A-Z0-9]{10})', url)
    if match:
        return match.group(1)
    return None

# ---------- Auto Resume ----------
save_path = "../data/raw/review_urls.txt"
os.makedirs(os.path.dirname(save_path), exist_ok=True)

collected_urls = set()
collected_asins = set()

if os.path.exists(save_path):
    with open(save_path, "r") as f:
        for line in f:
            url = line.strip()
            asin = extract_asin(url)
            if url:
                collected_urls.add(url)
            if asin:
                collected_asins.add(asin)

print(f"🟡 Loaded {len(collected_urls)} URLs and {len(collected_asins)} ASINs from previous runs.")

# ---------- Start Scraping ----------
page = 1
max_pages = 50

base_url = "https://www.amazon.in/s?i=electronics&rh=n%3A976419031&fs=true"
driver.get(base_url)
time.sleep(5)

try:
    while page <= max_pages and len(collected_urls) < 50:
        if not driver.window_handles:
            print("❌ All browser windows are closed. Exiting.")
            break

        driver.switch_to.window(driver.window_handles[0])

        print(f"\n🔍 Scanning page {page}")
        time.sleep(4)

        products = driver.find_elements(By.XPATH, "//div[@data-component-type='s-search-result']")

        for product in products:
            try:
                link_elem = product.find_element(By.XPATH, ".//a[contains(@class, 'a-link-normal s-no-outline')]")
                ActionChains(driver).key_down(Keys.CONTROL).click(link_elem).key_up(Keys.CONTROL).perform()
                time.sleep(3)

                driver.switch_to.window(driver.window_handles[-1])
                time.sleep(3)

                driver.execute_script("window.scrollTo(0, document.body.scrollHeight * 0.5);")
                time.sleep(2)

                try:
                    see_reviews_btn = driver.find_element(By.XPATH, "//a[contains(@data-hook, 'see-all-reviews-link-foot')]")
                    see_reviews_btn.click()
                    time.sleep(3)
                except NoSuchElementException:
                    print("ℹ️ No 'See all reviews' link found.")
                    driver.close()
                    driver.switch_to.window(driver.window_handles[0])
                    continue

                time.sleep(3)
                try:
                    count_elem = driver.find_element(By.XPATH, "//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]")
                    count_text = count_elem.text.strip()
                    print(f"🔹 Raw count text: {count_text}")

                    match = re.search(r'([\d,]+)\s+with reviews', count_text)
                    if match:
                        review_count = parse_review_count(match.group(1))
                        print(f"🔹 Written reviews found: {review_count}")

                        if review_count >= 500:
                            review_url = driver.current_url
                            asin = extract_asin(review_url)

                            if asin and asin not in collected_asins:
                                collected_asins.add(asin)
                                collected_urls.add(review_url)
                                print(f"✅ Saved: {review_url}")
                                with open(save_path, "a") as f:
                                    f.write(review_url + "\n")
                            else:
                                print(f"⚠️ Skipped duplicate ASIN: {asin}")

                    else:
                        print("❌ Could not extract written review count.")

                except Exception as e:
                    print(f"❌ Failed to extract review count: {e}")

                driver.close()
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(2)

            except Exception as e:
                print(f"⚠️ Skipped product due to: {e}")
                try:
                    if len(driver.window_handles) > 1:
                        driver.close()
                        driver.switch_to.window(driver.window_handles[0])
                except:
                    pass
                continue

        if len(collected_urls) >= 50:
            break

        try:
            next_btn = driver.find_element(By.XPATH, "//a[contains(@class, 's-pagination-next')]")
            driver.execute_script("arguments[0].scrollIntoView();", next_btn)
            time.sleep(1)
            next_btn.click()
            page += 1
            time.sleep(4)
        except:
            print("❌ No next page or failed to click.")
            break

except KeyboardInterrupt:
    print("\n🛑 Interrupted by user. Saving progress...")

except Exception as e:
    print(f"\n🚨 Unexpected error: {e}")

finally:
    driver.quit()
    print(f"\n✅ Done. Collected total {len(collected_urls)} unique review URLs with ≥500 written reviews.")
# Out:
# 🟡 Loaded 0 URLs and 0 ASINs from previous runs.
#
# 🔍 Scanning page 1
# 🔹 Raw count text: 21 total ratings, 1,165 with reviews
# 🔹 Written reviews found: 1165
# ✅ Saved: https://www.amazon.in/product-reviews/B0DSG8SNXH/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ❌ Failed to extract review count: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00FA80E3+60707]
# 	GetHandleVerifier [0x00FA8124+60772]
# 	(No symbol) [0x00DD0683]
# 	(No symbol) [0x00E18660]
# 	(No symbol) [0x00E189FB]
# 	(No symbol) [0x00E61022]
# 	(No symbol) [0x00E3D094]
# 	(No symbol) [0x00E5E824]
# 	(No symbol) [0x00E3CE46]
# 	(No symbol) [0x00E0C5D3]
# 	(No symbol) [0x00E0D424]
# 	GetHandleVerifier [0x011EBBC3+2435075]
# 	GetHandleVerifier [0x011E7163+2416035]
# 	GetHandleVerifier [0x0120350C+2531660]
# 	GetHandleVerifier [0x00FBF1B5+155125]
# 	GetHandleVerifier [0x00FC5B5D+182173]
# 	GetHandleVerifier [0x00FAF9B8+91640]
# 	GetHandleVerifier [0x00FAFB60+92064]
# 	GetHandleVerifier [0x00F9A620+4704]
# 	BaseThreadInitThunk [0x766F7BA9+25]
# 	RtlInitializeExceptionChain [0x7721C2EB+107]
# 	RtlClearBits [0x7721C26F+191]
#
# ❌ Failed to extract review count: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00FA80E3+60707]
# 	GetHandleVerifier [0x00FA8124+60772]
# 	(No symbol) [0x00DD0683]
# 	(No symbol) [0x00E18660]
# 	(No symbol) [0x00E189FB]
# 	(No symbol) [0x00E61022]
# 	(No symbol) [0x00E3D094]
# 	(No symbol) [0x00E5E824]
# 	(No symbol) [0x00E3CE46]
# 	(No symbol) [0x00E0C5D3]
# 	(No symbol) [0x00E0D424]
# 	GetHandleVerifier [0x011EBBC3+2435075]
# 	GetHandleVerifier [0x011E7163+2416035]
# 	GetHandleVerifier [0x0120350C+2531660]
# 	GetHandleVerifier [0x00FBF1B5+155125]
# 	GetHandleVerifier [0x00FC5B5D+182173]
# 	GetHandleVerifier [0x00FAF9B8+91640]
# 	GetHandleVerifier [0x00FAFB60+92064]
# 	GetHandleVerifier [0x00F9A620+4704]
# 	BaseThreadInitThunk [0x766F7BA9+25]
# 	RtlInitializeExceptionChain [0x7721C2EB+107]
# 	RtlClearBits [0x7721C26F+191]
#
# 🔹 Raw count text: 2,723 total ratings, 944 with reviews
# 🔹 Written reviews found: 944
# ✅ Saved: https://www.amazon.in/product-reviews/B0DFY3XCB6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 99 total ratings, 24,861 with reviews
# 🔹 Written reviews found: 24861
# ✅ Saved: https://www.amazon.in/product-reviews/B09TVVGXWS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 4,17,176 total ratings, 76,822 with reviews
# 🔹 Written reviews found: 76822
# ✅ Saved: https://www.amazon.in/product-reviews/B071Z8M4KX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ❌ Failed to extract review count: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00FA80E3+60707]
# 	GetHandleVerifier [0x00FA8124+60772]
# 	(No symbol) [0x00DD0683]
# 	(No symbol) [0x00E18660]
# 	(No symbol) [0x00E189FB]
# 	(No symbol) [0x00E61022]
# 	(No symbol) [0x00E3D094]
# 	(No symbol) [0x00E5E824]
# 	(No symbol) [0x00E3CE46]
# 	(No symbol) [0x00E0C5D3]
# 	(No symbol) [0x00E0D424]
# 	GetHandleVerifier [0x011EBBC3+2435075]
# 	GetHandleVerifier [0x011E7163+2416035]
# 	GetHandleVerifier [0x0120350C+2531660]
# 	GetHandleVerifier [0x00FBF1B5+155125]
# 	GetHandleVerifier [0x00FC5B5D+182173]
# 	GetHandleVerifier [0x00FAF9B8+91640]
# 	GetHandleVerifier [0x00FAFB60+92064]
# 	GetHandleVerifier [0x00F9A620+4704]
# 	BaseThreadInitThunk [0x766F7BA9+25]
# 	RtlInitializeExceptionChain [0x7721C2EB+107]
# 	RtlClearBits [0x7721C26F+191]
#
# ❌ Failed to extract review count: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00FA80E3+60707]
# 	GetHandleVerifier [0x00FA8124+60772]
# 	(No symbol) [0x00DD0683]
# 	(No symbol) [0x00E18660]
# 	(No symbol) [0x00E189FB]
# 	(No symbol) [0x00E61022]
# 	(No symbol) [0x00E3D094]
# 	(No symbol) [0x00E5E824]
# 	(No symbol) [0x00E3CE46]
# 	(No symbol) [0x00E0C5D3]
# 	(No symbol) [0x00E0D424]
# 	GetHandleVerifier [0x011EBBC3+2435075]
# 	GetHandleVerifier [0x011E7163+2416035]
# 	GetHandleVerifier [0x0120350C+2531660]
# 	GetHandleVerifier [0x00FBF1B5+155125]
# 	GetHandleVerifier [0x00FC5B5D+182173]
# 	GetHandleVerifier [0x00FAF9B8+91640]
# 	GetHandleVerifier [0x00FAFB60+92064]
# 	GetHandleVerifier [0x00F9A620+4704]
# 	BaseThreadInitThunk [0x766F7BA9+25]
# 	RtlInitializeExceptionChain [0x7721C2EB+107]
# 	RtlClearBits [0x7721C26F+191]
#
# 🔹 Raw count text: 23 total ratings, 4,675 with reviews
# 🔹 Written reviews found: 4675
# ✅ Saved: https://www.amazon.in/product-reviews/B0C8JB3G5W/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 565 total ratings, 1,461 with reviews
# 🔹 Written reviews found: 1461
# ✅ Saved: https://www.amazon.in/product-reviews/B07WFPL9PB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 4,018 total ratings, 1,830 with reviews
# 🔹 Written reviews found: 1830
# ✅ Saved: https://www.amazon.in/product-reviews/B0D22QWQHR/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 8,147 total ratings, 2,872 with reviews
# 🔹 Written reviews found: 2872
# ✅ Saved: https://www.amazon.in/product-reviews/B0D3R1JQ7D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 167 total ratings, 105 with reviews
# 🔹 Written reviews found: 105
# 🔹 Raw count text: 7,439 total ratings, 2,128 with reviews
# 🔹 Written reviews found: 2128
# ✅ Saved: https://www.amazon.in/product-reviews/B07WHQHNZC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 95,452 total ratings, 7,056 with reviews
# 🔹 Written reviews found: 7056
# ✅ Saved: https://www.amazon.in/product-reviews/B077BFH786/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 347 total ratings, 96 with reviews
# 🔹 Written reviews found: 96
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 73,264 total ratings, 11,793 with reviews
# 🔹 Written reviews found: 11793
# ✅ Saved: https://www.amazon.in/product-reviews/B098NS6PVG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,541 total ratings, 553 with reviews
# 🔹 Written reviews found: 553
# ✅ Saved: https://www.amazon.in/product-reviews/B0DH3J6LB9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 149 total ratings, 1,029 with reviews
# 🔹 Written reviews found: 1029
# ✅ Saved: https://www.amazon.in/product-reviews/B07R3386PP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 51,238 total ratings, 4,812 with reviews
# 🔹 Written reviews found: 4812
# ✅ Saved: https://www.amazon.in/product-reviews/B0BDRVFDKP/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,89,577 total ratings, 24,861 with reviews
# 🔹 Written reviews found: 24861
# ✅ Saved: https://www.amazon.in/product-reviews/B0CBTTCJL6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 3,661 total ratings, 1,421 with reviews
# 🔹 Written reviews found: 1421
# ✅ Saved: https://www.amazon.in/product-reviews/B0DFQ1R3W4/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 4,036 total ratings, 1,461 with reviews
# 🔹 Written reviews found: 1461
# ✅ Saved: https://www.amazon.in/product-reviews/B07WHS99FG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 49,471 total ratings, 5,776 with reviews
# 🔹 Written reviews found: 5776
# ✅ Saved: https://www.amazon.in/product-reviews/B0D2R2MXXJ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 2,366 total ratings, 774 with reviews
# 🔹 Written reviews found: 774
# ✅ Saved: https://www.amazon.in/product-reviews/B0DCNWN8NZ/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,89,577 total ratings, 24,861 with reviews
# 🔹 Written reviews found: 24861
# ⚠️ Skipped duplicate ASIN: B09TVVGXWS
# 🔹 Raw count text: 43 total ratings, 29 with reviews
# 🔹 Written reviews found: 29
# 🔹 Raw count text: 5,416 total ratings, 2,269 with reviews
# 🔹 Written reviews found: 2269
# ✅ Saved: https://www.amazon.in/product-reviews/B0D63CNLJ9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
#
# 🔍 Scanning page 2
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 43 total ratings, 29 with reviews
# 🔹 Written reviews found: 29
# 🔹 Raw count text: 1,254 total ratings, 1,165 with reviews
# 🔹 Written reviews found: 1165
# ✅ Saved: https://www.amazon.in/product-reviews/B0DSG51QM1/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ❌ Failed to extract review count: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00FA80E3+60707]
# 	GetHandleVerifier [0x00FA8124+60772]
# 	(No symbol) [0x00DD0683]
# 	(No symbol) [0x00E18660]
# 	(No symbol) [0x00E189FB]
# 	(No symbol) [0x00E61022]
# 	(No symbol) [0x00E3D094]
# 	(No symbol) [0x00E5E824]
# 	(No symbol) [0x00E3CE46]
# 	(No symbol) [0x00E0C5D3]
# 	(No symbol) [0x00E0D424]
# 	GetHandleVerifier [0x011EBBC3+2435075]
# 	GetHandleVerifier [0x011E7163+2416035]
# 	GetHandleVerifier [0x0120350C+2531660]
# 	GetHandleVerifier [0x00FBF1B5+155125]
# 	GetHandleVerifier [0x00FC5B5D+182173]
# 	GetHandleVerifier [0x00FAF9B8+91640]
# 	GetHandleVerifier [0x00FAFB60+92064]
# 	GetHandleVerifier [0x00F9A620+4704]
# 	BaseThreadInitThunk [0x766F7BA9+25]
# 	RtlInitializeExceptionChain [0x7721C2EB+107]
# 	RtlClearBits [0x7721C26F+191]
#
# ❌ Failed to extract review count: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00FA80E3+60707]
# 	GetHandleVerifier [0x00FA8124+60772]
# 	(No symbol) [0x00DD0683]
# 	(No symbol) [0x00E18660]
# 	(No symbol) [0x00E189FB]
# 	(No symbol) [0x00E61022]
# 	(No symbol) [0x00E3D094]
# 	(No symbol) [0x00E5E824]
# 	(No symbol) [0x00E3CE46]
# 	(No symbol) [0x00E0C5D3]
# 	(No symbol) [0x00E0D424]
# 	GetHandleVerifier [0x011EBBC3+2435075]
# 	GetHandleVerifier [0x011E7163+2416035]
# 	GetHandleVerifier [0x0120350C+2531660]
# 	GetHandleVerifier [0x00FBF1B5+155125]
# 	GetHandleVerifier [0x00FC5B5D+182173]
# 	GetHandleVerifier [0x00FAF9B8+91640]
# 	GetHandleVerifier [0x00FAFB60+92064]
# 	GetHandleVerifier [0x00F9A620+4704]
# 	BaseThreadInitThunk [0x766F7BA9+25]
# 	RtlInitializeExceptionChain [0x7721C2EB+107]
# 	RtlClearBits [0x7721C26F+191]
#
# 🔹 Raw count text: 5,645 total ratings, 1,409 with reviews
# 🔹 Written reviews found: 1409
# ✅ Saved: https://www.amazon.in/product-reviews/B0D5YCYS1G/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 170 total ratings, 90 with reviews
# 🔹 Written reviews found: 90
# 🔹 Raw count text: 53 total ratings, 47 with reviews
# 🔹 Written reviews found: 47
# 🔹 Raw count text: 1,66,327 total ratings, 48,961 with reviews
# 🔹 Written reviews found: 48961
# ✅ Saved: https://www.amazon.in/product-reviews/B01DEWVZ2C/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 4,871 total ratings, 1,660 with reviews
# 🔹 Written reviews found: 1660
# ✅ Saved: https://www.amazon.in/product-reviews/B0CVN4DNWY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 543 total ratings, 347 with reviews
# 🔹 Written reviews found: 347
# ❌ Failed to extract review count: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[contains(@data-hook, 'cr-filter-info-review-rating-count')]"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00FA80E3+60707]
# 	GetHandleVerifier [0x00FA8124+60772]
# 	(No symbol) [0x00DD0683]
# 	(No symbol) [0x00E18660]
# 	(No symbol) [0x00E189FB]
# 	(No symbol) [0x00E61022]
# 	(No symbol) [0x00E3D094]
# 	(No symbol) [0x00E5E824]
# 	(No symbol) [0x00E3CE46]
# 	(No symbol) [0x00E0C5D3]
# 	(No symbol) [0x00E0D424]
# 	GetHandleVerifier [0x011EBBC3+2435075]
# 	GetHandleVerifier [0x011E7163+2416035]
# 	GetHandleVerifier [0x0120350C+2531660]
# 	GetHandleVerifier [0x00FBF1B5+155125]
# 	GetHandleVerifier [0x00FC5B5D+182173]
# 	GetHandleVerifier [0x00FAF9B8+91640]
# 	GetHandleVerifier [0x00FAFB60+92064]
# 	GetHandleVerifier [0x00F9A620+4704]
# 	BaseThreadInitThunk [0x766F7BA9+25]
# 	RtlInitializeExceptionChain [0x7721C2EB+107]
# 	RtlClearBits [0x7721C26F+191]
#
# 🔹 Raw count text: 543 total ratings, 347 with reviews
# 🔹 Written reviews found: 347
# 🔹 Raw count text: 167 total ratings, 105 with reviews
# 🔹 Written reviews found: 105
# 🔹 Raw count text: 3,456 total ratings, 1,715 with reviews
# 🔹 Written reviews found: 1715
# ✅ Saved: https://www.amazon.in/product-reviews/B0CZ3ZPD8B/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 1 total rating, 1 with review
# ❌ Could not extract written review count.
# 🔹 Raw count text: 56 total ratings, 1,473 with reviews
# 🔹 Written reviews found: 1473
# ✅ Saved: https://www.amazon.in/product-reviews/B097JJ2CK6/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 6,696 total ratings, 1,914 with reviews
# 🔹 Written reviews found: 1914
# ✅ Saved: https://www.amazon.in/product-reviews/B0CRH561RC/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 160 total ratings, 105 with reviews
# 🔹 Written reviews found: 105
# 🔹 Raw count text: 1,819 total ratings, 1,421 with reviews
# 🔹 Written reviews found: 1421
# ✅ Saved: https://www.amazon.in/product-reviews/B0D7HZ3KK9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 5,063 total ratings, 862 with reviews
# 🔹 Written reviews found: 862
# ✅ Saved: https://www.amazon.in/product-reviews/B0BZ3WNQ5T/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 3,327 total ratings, 645 with reviews
# 🔹 Written reviews found: 645
# ✅ Saved: https://www.amazon.in/product-reviews/B0CHX1W1XY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 130 total ratings, 785 with reviews
# 🔹 Written reviews found: 785
# ✅ Saved: https://www.amazon.in/product-reviews/B0D7MNX9Y5/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 51,238 total ratings, 4,812 with reviews
# 🔹 Written reviews found: 4812
# ✅ Saved: https://www.amazon.in/product-reviews/B0BDYVC5TD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 467 total ratings, 1,001 with reviews
# 🔹 Written reviews found: 1001
# ✅ Saved: https://www.amazon.in/product-reviews/B0DLW427YG/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,66,977 total ratings, 28,906 with reviews
# 🔹 Written reviews found: 28906
# ✅ Saved: https://www.amazon.in/product-reviews/B09N3ZNHTY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 77,622 total ratings, 13,869 with reviews
# 🔹 Written reviews found: 13869
# ✅ Saved: https://www.amazon.in/product-reviews/B0D18192T2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,52,539 total ratings, 17,830 with reviews
# 🔹 Written reviews found: 17830
# ✅ Saved: https://www.amazon.in/product-reviews/B0C5RK3X6F/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 3,578 total ratings, 1,977 with reviews
# 🔹 Written reviews found: 1977
# ✅ Saved: https://www.amazon.in/product-reviews/B0DFMHM9CM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# ℹ️ No 'See all reviews' link found.
#
# 🔍 Scanning page 3
# 🔹 Raw count text: 43 total ratings, 29 with reviews
# 🔹 Written reviews found: 29
# ℹ️ No 'See all reviews' link found.
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 173 total ratings, 10,360 with reviews
# 🔹 Written reviews found: 10360
# ✅ Saved: https://www.amazon.in/product-reviews/B09R24JBYV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,022 total ratings, 418 with reviews
# 🔹 Written reviews found: 418
# 🔹 Raw count text: 7,020 total ratings, 597 with reviews
# 🔹 Written reviews found: 597
# ✅ Saved: https://www.amazon.in/product-reviews/B0DZHXTPK1/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 5,446 total ratings, 2,674 with reviews
# 🔹 Written reviews found: 2674
# ✅ Saved: https://www.amazon.in/product-reviews/B0CP54XBWN/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 80 total ratings, 9,636 with reviews
# 🔹 Written reviews found: 9636
# ✅ Saved: https://www.amazon.in/product-reviews/B0DCZ3WDTB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 43,053 total ratings, 5,696 with reviews
# 🔹 Written reviews found: 5696
# ✅ Saved: https://www.amazon.in/product-reviews/B01HJI0FS2/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 923 total ratings, 1,462 with reviews
# 🔹 Written reviews found: 1462
# ✅ Saved: https://www.amazon.in/product-reviews/B07WHRZRD7/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 13,187 total ratings, 1,803 with reviews
# 🔹 Written reviews found: 1803
# ✅ Saved: https://www.amazon.in/product-reviews/B082WYMTWF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 1,89,577 total ratings, 24,861 with reviews
# 🔹 Written reviews found: 24861
# ✅ Saved: https://www.amazon.in/product-reviews/B0B3MNYGTW/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 2,472 total ratings, 1,001 with reviews
# 🔹 Written reviews found: 1001
# ✅ Saved: https://www.amazon.in/product-reviews/B0DLW4QD72/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 49,471 total ratings, 5,776 with reviews
# 🔹 Written reviews found: 5776
# ✅ Saved: https://www.amazon.in/product-reviews/B0D2R26HFV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 1 total rating, 1 with review
# ❌ Could not extract written review count.
# 🔹 Raw count text: 2,795 total ratings, 298 with reviews
# 🔹 Written reviews found: 298
# 🔹 Raw count text: 2,472 total ratings, 1,001 with reviews
# 🔹 Written reviews found: 1001
# ✅ Saved: https://www.amazon.in/product-reviews/B0DLW1L5PR/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 38,754 total ratings, 4,829 with reviews
# 🔹 Written reviews found: 4829
# ✅ Saved: https://www.amazon.in/product-reviews/B07XCM6T4N/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 3,936 total ratings, 1,320 with reviews
# 🔹 Written reviews found: 1320
# ✅ Saved: https://www.amazon.in/product-reviews/B0BG8LZNYL/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 22,442 total ratings, 1,702 with reviews
# 🔹 Written reviews found: 1702
# ✅ Saved: https://www.amazon.in/product-reviews/B00LVMTA2A/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 16,945 total ratings, 1,982 with reviews
# 🔹 Written reviews found: 1982
# ✅ Saved: https://www.amazon.in/product-reviews/B00MVV81MK/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 3,327 total ratings, 645 with reviews
# 🔹 Written reviews found: 645
# ✅ Saved: https://www.amazon.in/product-reviews/B0CHX2F5QT/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 2,472 total ratings, 1,001 with reviews
# 🔹 Written reviews found: 1001
# ✅ Saved: https://www.amazon.in/product-reviews/B0DLW44CGS/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 14,482 total ratings, 2,570 with reviews
# 🔹 Written reviews found: 2570
# ✅ Saved: https://www.amazon.in/product-reviews/B09ZPL5VYM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,160 total ratings, 418 with reviews
# 🔹 Written reviews found: 418
# 🔹 Raw count text: 3,327 total ratings, 645 with reviews
# 🔹 Written reviews found: 645
# ✅ Saved: https://www.amazon.in/product-reviews/B0CHX3TW6X/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# 🔹 Raw count text: 1,541 total ratings, 553 with reviews
# 🔹 Written reviews found: 553
# ✅ Saved: https://www.amazon.in/product-reviews/B0DH8BZ7V9/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews
# ℹ️ No 'See all reviews' link found.
# 🔹 Raw count text: 1,254 total ratings, 1,165 with reviews
# 🔹 Written reviews found: 1165
# ⚠️ Skipped duplicate ASIN: B0DSG8SNXH
# 🔹 Raw count text: 3,578 total ratings, 1,977 with reviews
# 🔹 Written reviews found: 1977
# ⚠️ Skipped duplicate ASIN: B0DFMHM9CM
#
# ✅ Done. Collected total 57 unique review URLs with ≥500 written reviews.

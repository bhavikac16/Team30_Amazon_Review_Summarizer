# %%
import pandas as pd
from textblob import TextBlob
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# # **Sentiment Analysis**

# %%
# !pip install nltk textblob
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
# Download stopwords from nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab') # Download the punkt_tab data for English tokenization
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Step 2: Load the dataset
# Replace with the path to your reviews CSV file
reviews_file_path = "/content/updated_amazon_reviews.csv"
reviews_df = pd.read_csv(reviews_file_path)

# %%
# Check the first few rows of the dataset
print(reviews_df.head())
# Out:
#     productID  overall_rating  \
# 0  B0DSG8SNXH             4.3
# 1  B0DFY3XCB6             4.0
# 2  B09TVVGXWS             4.1
# 3  B071Z8M4KX             4.1
# 4  B0C8JB3G5W             4.2
#
#                                              review1  \
# 0  Boult newly launched Z20 truly wireless blueto...
# 1  I recently purchased the Samsung Galaxy M05 fo...
# 2  I have been a user of OnePlus Bullets wireless...
# 3  I recently purchased the boAt BassHeads 100 in...
# 4  best wireless earphones for 1600. very sleek l...
#
#                                              review2  \
# 0  Good price and These earbuds are really good. ...
# 1  All I can say it's worth it considering that P...
# 2  There is nothing wrong with the looks of the B...
# 3  Good product at this price.\nBuild Quality was...
# 4  The OnePlus Buds 2R offer impressive value at ...
#
#                                              review3  \
# 0  With their deep bass and crystal-clear highs, ...
# 1  I'm thoroughly impressed with this phone! The ...
# 2  If you're on the lookout for a solid pair of w...
# 3  Nice product... sound does not break.. sound q...
# 4  1. Since 2023 September, they have been droppe...
#
#                                              review4  \
# 0  Impressed with these buds! Crisp and clear aud...
# 1  Processor- Slow processor but i guess you cant...
# 2  Bought it over a year ago and still works grea...
# 3  Better than other products with this price lis...
# 4  Comfortable. Sound quality good.The buds are r...
#
#                                              review5  \
# 0  With their deep bass and crystal-clear highs, ...
# 1  Whatever I am doing right is on that phone thi...
# 2  I recently purchased the OnePlus Bullets Wirel...
# 3  Delivery agent was very polite and respectful....
# 4  Great product with good battery backup and ver...
#
#                                              review6  \
# 0  Made in india is the best feeling what I recen...
# 1  Its good phone under 7 thousand category, if s...
# 2  The OnePlus Bullets Wireless Z2 ANC is the lat...
# 3  Good and quite comfortable. The ear buds nicel...
# 4  Very good sound quality. Touch buttons work ve...
#
#                                              review7  \
# 0  These earbuds were created with comfort in min...
# 1  According to the price best mobile\nPros\nBig ...
# 2  I recently purchased your headphone, but I am ...
# 3  A very basic 90's earphones, was a gift to my ...
# 4  I recently bought these EarPods, and while the...
#
#                                              review8  ...  \
# 0  The Boult Audio Z20 truly wireless earbuds off...  ...
# 1            Without charger not good for this price  ...
# 2  Good sound quality and durable built. However,...  ...
# 3  Everything available within this price.\n(case...  ...
# 4  I’m a big fan of headphones—some might even ca...  ...
#
#                                  review491  \
# 0                     I am using the Boult
# 1                  This phone is kinda meh
# 2                 Always good Lets see for
# 3  Wire is thin and it has more changes to
# 4              Good product quick delivery
#
#                                            review492  \
# 0                      At first I wasnt sure how itd
# 1  Best for basic users Look wise very attractive...
# 2                                              Super
# 3                                  Great Clear sound
# 4           Best in battery backup sound quality ear
#
#                                            review493  \
# 0  These earbud have completely redefined my expe...
# 1  I have been using this phone for the past two ...
# 2  I have been using it for more than a week now ...
# 3                                          Very Good
# 4           Quality is good and sound is really good
#
#                                            review494  \
# 0                            Loved this product  its
# 1                                తకకవ ఖరచత ఎకకవ ఉపయగ
# 2                                  No battery backup
# 3  I got this product 440 400 product 40 delivery...
# 4                        Worth the money ease to use
#
#                                     review495  \
# 0  Great build quality  range is pretty good
# 1                                   Very good
# 2                                        Good
# 3                                   Very Good
# 4                 Call quality was excellence
#
#                                            review496  \
# 0  Honestly Im really loving the premium look of ...
# 1                               Selfies are not good
# 2                                               Nice
# 3                                   This is a Type C
# 4                            Good Sound and good Mic
#
#                                            review497  \
# 0  The sound is clear with strong bass and calls ...
# 1                                               Good
# 2                                       Best quality
# 3       Awesome but seems now the phone company have
# 4                                               Good
#
#                                   review498  \
# 0  Ive been using these TWS earphones for a
# 1                                      good
# 2                                 Very good
# 3              Being using it for 46 months
# 4                              Good quality
#
#                                            review499  \
# 0                 I have been using this earbuds for
# 1                           The phone is good but it
# 2                                            Awesome
# 3                                               Good
# 4  Awesome Value for money but I only one problem...
#
#                                            review500
# 0  Not bad ovaroll all good Bass thaggedele So im...
# 1                           Well its a Samsung phone
# 2  Im thoroughly impressed with this Bluetooth wi...
# 3  My second purchase of boat earphones and they ...
# 4                 The product is good in quality and
#
# [5 rows x 502 columns]

# %%
# Step 2: Preprocess the reviews (clean the text)
def clean_text(text):
    """
    This function cleans the review text by:
    - Lowercasing
    - Removing punctuation
    - Tokenizing
    - Removing stopwords
    """
    if isinstance(text, str):  # Ensure the text is a string before processing
        # Convert text to lowercase
        text = text.lower()

        # Remove punctuation
        text = ''.join([char for char in text if char not in string.punctuation])

        # Tokenize the text
        words = word_tokenize(text)

        # Remove stopwords
        stop_words = set(nltk.corpus.stopwords.words('english'))
        cleaned_words = [word for word in words if word not in stop_words]

        return ' '.join(cleaned_words)
    else:
        return ""  # If it's not a string, return an empty string

# %%
nltk.download('vader_lexicon')

# Define the sentiment scores function using VADER
def sentiment_scores(sentence):
    senti = SentimentIntensityAnalyzer()
    sentiment_dict = senti.polarity_scores(sentence)  # This line returns the polarity for sentence

    # Classifying sentiment based on the compound score
    if sentiment_dict['compound'] >= 0.05:
        return "Positive", sentiment_dict['pos'], sentiment_dict['compound']
    elif sentiment_dict['compound'] <= -0.05:
        return "Negative", sentiment_dict['neg'], sentiment_dict['compound']
    else:
        return "Neutral", sentiment_dict['neu'], sentiment_dict['compound']
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Step 2: Perform Sentiment Analysis for each review
def analyze_product_reviews(product_name, reviews):
    sentiment_counts = {'Positive': 0, 'Neutral': 0, 'Negative': 0}
    for review in reviews:
        if isinstance(review, str) and review.strip():
            sentiment, _, _ = sentiment_scores(review)
            sentiment_counts[sentiment] += 1
    return sentiment_counts

# %%
# Step 3: Analyze sentiment for each product
sentiment_results = {}

for product_name in reviews_df['productID'].unique():
    # Get reviews for the current product (columns review1 to review500)
    product_reviews = reviews_df[reviews_df['productID'] == product_name].iloc[:, 2:].values.flatten()

    # Analyze sentiment for the current product
    sentiment_counts = analyze_product_reviews(product_name, product_reviews)

    # Save the results
    sentiment_results[product_name] = sentiment_counts

# %%
# Step 4: Display the sentiment results
# Convert results to a DataFrame for better visualization
sentiment_df = pd.DataFrame.from_dict(sentiment_results, orient='index')

# Ensure the DataFrame has the correct columns: Negative, Neutral, Positive
sentiment_df = sentiment_df[['Negative', 'Neutral', 'Positive']]

# Fill NaN values (if any) with 0 (in case a product has no sentiment for a certain category)
sentiment_df = sentiment_df.fillna(0)

# Display the sentiment distribution for each product
print("Sentiment distribution for each product:")
print(sentiment_df)
# Out:
# Sentiment distribution for each product:
#             Negative  Neutral  Positive
# B0DSG8SNXH         8      126       366
# B0DFY3XCB6        48      123       329
# B09TVVGXWS        48      108       344
# B071Z8M4KX        71       73       356
# B0C8JB3G5W        50       91       359
# B07WFPL9PB        22       58       420
# B0D22QWQHR        28       70       402
# B0D3R1JQ7D        62       41       397
# B07WHQHNZC        24      110       366
# B077BFH786        12       85       403
# B098NS6PVG        40       84       376
# B0DH3J6LB9        22       85       393
# B07R3386PP        28      126       346
# B0BDRVFDKP        19       79       402
# B0CBTTCJL6        36      114       350
# B0DFQ1R3W4        37      114       349
# B07WHS99FG        14       61       425
# B0D2R2MXXJ        28       59       408
# B0DCNWN8NZ        15      100       385
# B0D63CNLJ9        16      103       377
# B0DSG51QM1         9      116       375
# B0D5YCYS1G        48       60       392
# B01DEWVZ2C        52       77       371
# B0CVN4DNWY        34      119       344
# B0CZ3ZPD8B        97      119       284
# B097JJ2CK6        25       80       395
# B0CRH561RC        37       89       374
# B0D7HZ3KK9        48      104       348
# B0BZ3WNQ5T       117      109       274
# B0CHX1W1XY        25       85       384
# B0D7MNX9Y5        51       96       350
# B0BDYVC5TD        19       65       416
# B0DLW427YG        21      107       372
# B09N3ZNHTY        23       96       378
# B0D18192T2        17      127       356
# B0C5RK3X6F        57       76       360
# B0DFMHM9CM        24       80       396
# B09R24JBYV        45      129       326
# B0DZHXTPK1        70      141       289
# B0CP54XBWN        76      102       314
# B0DCZ3WDTB        55      113       332
# B01HJI0FS2        17       72       411
# B07WHRZRD7        16       58       426
# B082WYMTWF        30      149       321
# B0B3MNYGTW        45      107       348
# B0DLW4QD72        18       87       395
# B0D2R26HFV        26       67       403
# B0DLW1L5PR        32      101       367
# B07XCM6T4N        23       74       403
# B0BG8LZNYL        34       92       374
# B00LVMTA2A        40      132       328
# B00MVV81MK        79      106       309
# B0CHX2F5QT        32       97       366
# B0DLW44CGS        26       91       383
# B09ZPL5VYM        36       97       367
# B0CHX3TW6X        34       98       365
# B0DH8BZ7V9        19       84       397

# %%
# Step 5: Save the sentiment analysis results to a CSV file
output_file_path = 'product_sentiment_results_vader.csv'
sentiment_df.to_csv(output_file_path, index=True)

output_file_path
# Out:
# 'product_sentiment_results_vader.csv'

# %% [markdown]
# # **Aspect based Opinion Mining**

# %%
import spacy
# Load the spaCy model for extracting aspects (noun chunks)
nlp = spacy.load("en_core_web_sm")

# %%
# Initialize VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# %%
# Function for extracting aspects (noun chunks) from a review using spaCy
def extract_aspects(review):
    doc = nlp(review)
    aspects = []
    # Extract noun chunks (e.g., "battery life", "camera quality")
    for chunk in doc.noun_chunks:
        aspects.append(chunk.text.lower())  # Store in lowercase for uniformity
    return aspects

# %%
# Function to perform sentiment analysis using VADER (already available sentiment scores)
def sentiment_scores(sentence):
    sentiment_dict = sia.polarity_scores(sentence)
    if sentiment_dict['compound'] >= 0.05:
        return "Positive"
    elif sentiment_dict['compound'] <= -0.05:
        return "Negative"
    else:
        return "Neutral"

# %%
# Function to perform aspect-based sentiment analysis for a list of reviews
def aspect_based_opinion_mining(reviews):
    aspect_sentiment = {}  # Dictionary to store aspect-based sentiment

    for review in reviews:
        if isinstance(review, str) and review.strip():  # Ensure the review is a valid string and not NaN
            aspects = extract_aspects(review)

            # For each aspect, perform sentiment analysis
            for aspect in aspects:
                sentiment = sentiment_scores(aspect)
                if aspect not in aspect_sentiment:
                    aspect_sentiment[aspect] = {'Positive': 0, 'Neutral': 0, 'Negative': 0}

                # Increment the sentiment count for the aspect
                aspect_sentiment[aspect][sentiment] += 1

    return aspect_sentiment

# %%
# Step 1: Perform Aspect-Based Opinion Mining for each product
aspect_sentiment_results = {}

for product_name in reviews_df['productID'].unique():
    # Get reviews for the current product (columns Review_1 to Review_500)
    product_reviews = reviews_df[reviews_df['productID'] == product_name].iloc[:, 2:].values.flatten()

    # Perform Aspect-Based Opinion Mining
    sentiment_counts = aspect_based_opinion_mining(product_reviews)

    # Save the results
    aspect_sentiment_results[product_name] = sentiment_counts

# %%
# Step 2: Convert results into a DataFrame for better visualization
aspect_sentiment_df = pd.DataFrame.from_dict(aspect_sentiment_results, orient='index')

# Transpose the DataFrame to have aspects as rows and sentiment categories as columns
aspect_sentiment_df = aspect_sentiment_df.T

# Fill NaN values with 0 (if an aspect has no sentiment for a product)
aspect_sentiment_df = aspect_sentiment_df.fillna(0)

# %%
# Step 3: Save the aspect-based sentiment analysis results to a CSV file
output_file_path = 'aspect_based_sentiment_results.csv'
aspect_sentiment_df.to_csv(output_file_path, index=True)

# Print the aspect-based sentiment analysis for each product
# print("Aspect-Based Sentiment Analysis Results:")

for product_name, sentiment_counts in aspect_sentiment_results.items():
    print(f"\nProduct: {product_name}")
    for aspect, counts in sentiment_counts.items():
        print(f"  Aspect: {aspect.capitalize()} - Positive: {counts['Positive']}, Neutral: {counts['Neutral']}, Negative: {counts['Negative']}")

output_file_path  # Return the path of the saved file for downloading
# Out:
# Product: B0DSG8SNXH
#   Aspect: Boult - Positive: 0, Neutral: 9, Negative: 0
#   Aspect: Z20 - Positive: 0, Neutral: 11, Negative: 0
#   Aspect: I - Positive: 0, Neutral: 254, Negative: 0
#   Aspect: These earbuds - Positive: 0, Neutral: 47, Negative: 0
#   Aspect: The design - Positive: 0, Neutral: 15, Negative: 0
#   Aspect: Good & very compact full , very light weight - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Ears - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: A long time - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: The sound quality - Positive: 0, Neutral: 30, Negative: 0
#   Aspect: Movies - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Series - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Noise cancellation - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Mic quality - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Battery life - Positive: 0, Neutral: 24, Negative: 0
#   Aspect: Fast charging speed - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Bluetooth connectivity - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Any issue - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: It - Positive: 0, Neutral: 101, Negative: 0
#   Aspect: You - Positive: 0, Neutral: 36, Negative: 0
#   Aspect: Bluetooth - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Their performance - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A great budget friendly earbuds - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: A great performance - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: This price range - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Good price - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: The sound - Positive: 0, Neutral: 24, Negative: 0
#   Aspect: Bass - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: They - Positive: 0, Neutral: 81, Negative: 0
#   Aspect: Battery - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Music - Positive: 0, Neutral: 21, Negative: 0
#   Aspect: Calls - Positive: 0, Neutral: 34, Negative: 0
#   Aspect: Travel - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Stylish design - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The price - Positive: 0, Neutral: 25, Negative: 0
#   Aspect: Their deep bass and crystal-clear highs - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The boult z20 earbuds - Positive: 0, Neutral: 41, Negative: 0
#   Aspect: An amazing audio experience - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: That - Positive: 0, Neutral: 21, Negative: 0
#   Aspect: Every note - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Videos - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Phone calls - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: These ergonomic earbuds - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Comfort - Positive: 11, Neutral: 0, Negative: 0
#   Aspect: Mind - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Snug - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Cozy - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Extended use - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Ambient noise - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Active noise cancellation - Positive: 4, Neutral: 0, Negative: 0
#   Aspect: Anc - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: A continuous listening experience - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Up to 6 hours - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: A single charge - Positive: 0, Neutral: 8, Negative: 0
#   Aspect: An additional 24 hours - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: The charging case - Positive: 0, Neutral: 8, Negative: 0
#   Aspect: The device - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Unbroken calls - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Continuous music streaming - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: The strong and dependable bluetooth connection - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: A great option - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: Anyone - Positive: 0, Neutral: 8, Negative: 0
#   Aspect: Premium wireless earbuds - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: A reasonable cost - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Their stylish design - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Good sound quality - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: These buds - Positive: 0, Neutral: 18, Negative: 0
#   Aspect: Comfortable fit - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Long battery life - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Affordable price - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Great value - Positive: 13, Neutral: 0, Negative: 0
#   Aspect: Gaming - Positive: 0, Neutral: 10, Negative: 0
#   Aspect: Their quality - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Performance - Positive: 0, Neutral: 8, Negative: 0
#   Aspect: Reliable operation - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: India - Positive: 0, Neutral: 13, Negative: 0
#   Aspect: The best feeling - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: What - Positive: 0, Neutral: 12, Negative: 0
#   Aspect: This product - Positive: 0, Neutral: 11, Negative: 0
#   Aspect: The audio - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Deep bass and well-balanced soundscape - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The earbuds - Positive: 0, Neutral: 21, Negative: 0
#   Aspect: Them - Positive: 0, Neutral: 51, Negative: 0
#   Aspect: Long hours - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Use - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: The battery backup - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: The fast-charging feature - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: A lifesaver - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Hours - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Playback - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Just a quick 10-minute charge - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Pairing - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: The connection - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Seamless inbuilt enc mode - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Clear conversations - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: All times - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The z20 earbuds - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Great sound - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Reliability - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: An affordable price - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Premium earbuds - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: A budget - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The boult audio z20 truly wireless earbuds - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: An impressive blend - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: Value - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: The budget segment - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: A detailed review - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Sound quality - Positive: 0, Neutral: 21, Negative: 0
#   Aspect: Connectivity - Positive: 0, Neutral: 9, Negative: 0
#   Aspect: Quality - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Sound quality
# the z20 earbuds - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Boom x™ tech drivers - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Rich bass - Positive: 8, Neutral: 0, Negative: 0
#   Aspect: Clear vocals - Positive: 4, Neutral: 0, Negative: 0
#   Aspect: The listening experience - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The z20 - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Fast and stable connections - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Minimal latency - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The blink & pair™ technology - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Quick pairing - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A sleek metallic finish - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Ear - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Each - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: An ipx5 water resistance rating - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Workouts - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Outdoor activities - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: An impressive total playback time - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Up to 51 hours - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Up to 5-6 hours - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Final verdict - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: This price value - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: The boult audio z20 - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Excellent value - Positive: 8, Neutral: 0, Negative: 0
#   Aspect: Money - Positive: 0, Neutral: 22, Negative: 0
#   Aspect: Solid performance - Positive: 4, Neutral: 0, Negative: 0
#   Aspect: An ideal choice - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Budget-conscious consumers - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Reliable wireless earbuds - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Everyday use - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Any issues - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Ear buds - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A regular music lover - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: Someone - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Who - Positive: 0, Neutral: 10, Negative: 0
#   Aspect: The boult audio z20 earbuds - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: A few weeks - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: My ears - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Long use - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The bass - Positive: 0, Neutral: 9, Negative: 0
#   Aspect: Vocals - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: High volumes - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The battery life - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: A few days - Positive: 0, Neutral: 9, Negative: 0
#   Aspect: The case - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: The fast charging - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The enc - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The gaming mode - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A noticeable difference - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: My phone - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Bluetooth connection - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The only things - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Maybe wireless charging - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Great solid earbuds - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: The boult z20 - Positive: 0, Neutral: 21, Negative: 0
#   Aspect: A bit - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Good bass - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Both - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: This price - Positive: 0, Neutral: 16, Negative: 0
#   Aspect: Extended periods - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: No problems - Positive: 0, Neutral: 0, Negative: 2
#   Aspect: The look - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: An entire day - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: No problem - Positive: 0, Neutral: 0, Negative: 3
#   Aspect: A ton - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Extra power - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Fast charging - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: A godsend - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: 10 minutes - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: No dropouts - Positive: 0, Neutral: 0, Negative: 1
#   Aspect: Lag - Positive: 0, Neutral: 0, Negative: 1
#   Aspect: Touch controls - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: The noise cancellation - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Loud areas - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: People - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Me - Positive: 0, Neutral: 17, Negative: 0
#   Aspect: Excellent sound quality
#
# long battery life - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Quick charge
#
# comfortable fit
#
# good call quality
#
# easy pairing - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Overall excellent product - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Budget friendly price - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Pine green - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Strong bass - Positive: 10, Neutral: 0, Negative: 0
#   Aspect: The battery - Positive: 0, Neutral: 8, Negative: 0
#   Aspect: The zen™ enc mic - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Noisy places - Positive: 0, Neutral: 0, Negative: 2
#   Aspect: The touch controls - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Which - Positive: 0, Neutral: 20, Negative: 0
#   Aspect: Place - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: The low latency - Positive: 0, Neutral: 0, Negative: 2
#   Aspect: A product - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A great mix - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Music and gaming lovers - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: These tws earphones - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: A couple - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Weeks - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: The ears - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Any pocket - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Fuss - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The build quality - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Everything - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: The matte - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The sturdy hinge - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Durability - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The magnets - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Crisp highs - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Balanced mids - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Punchy bass - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: My expectations - Positive: 0, Neutral: 17, Negative: 0
#   Aspect: Good noise isolation - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Both ends - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A pair - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Tws earphones - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Elegant design - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Premium build quality - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: These - Positive: 0, Neutral: 19, Negative: 0
#   Aspect: An excellent choice - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Absolutely incredible sound quality - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Several earbuds - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Crystal - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Deep bass - Positive: 0, Neutral: 17, Negative: 0
#   Aspect: Crisp mids - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Smooth highs - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Music lovers - Positive: 7, Neutral: 0, Negative: 0
#   Aspect: Audiophiles - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Distractions - Positive: 0, Neutral: 0, Negative: 1
#   Aspect: Busy environments - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Long workouts - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Commutes - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A recharge - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Runs - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Intense sessions - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: The gym - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The bluetooth connection - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Zero lag - Positive: 0, Neutral: 0, Negative: 1
#   Aspect: The boult z20 truly wireless bluetooth earbuds - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: Impressive 51-hour playtime and fast type-c charging - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Indian users - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Zen™ enc mics - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Clear calling and low latency - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Smooth gaming - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Rich bass drivers - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Immersive sound quality - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Long-lasting wear - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Discomfort - Positive: 0, Neutral: 0, Negative: 2
#   Aspect: Their sleek jet black design - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A premium feel - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Style - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Affordability - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The tws segment - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Good product - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Guys - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The newly launched boult z20 truly wireless bluetooth earbuds - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: A punch - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Terms - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Features - Positive: 0, Neutral: 2, Negative: 0
#   Aspect:
Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Thanks - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Good product - Positive: 27, Neutral: 0, Negative: 0
#   Aspect: The build quality - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Trouble - Positive: 0, Neutral: 0, Negative: 9
#   Aspect: My ipad - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Times - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: This product - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Its speed - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Data transfer speed - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Price range - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Superior - Positive: 10, Neutral: 0, Negative: 0
#   Aspect: Metal - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: A very good product - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: My mobile usb - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: 2.0 support - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Working fine - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: Product - Positive: 0, Neutral: 8, Negative: 0
#   Aspect: Good works - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Large data - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Transfer speeds - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Good quality - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: The connection - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: A side - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Price - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Nice work - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: A jabra headphone - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: That - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: A c type bt connector - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: This c - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Usb adaptor - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Very nice product multipurpose - Positive: 4, Neutral: 0, Negative: 0
#   Aspect: Mouse - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Connection - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Laptop - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Good converter - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Usb a - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: C type - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Works - Positive: 0, Neutral: 17, Negative: 0
#   Aspect: Quality - Positive: 0, Neutral: 9, Negative: 0
#   Aspect: Good
# function - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Recommendation - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Your pendrives - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Your mobile - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Type-c pin - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: We - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: The wire - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: They - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Their contact - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A great fit - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: Type-c pendrives - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A small hole - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Loop - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A keychain - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Lanyard - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Which - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Your controller - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Very cheapest and very best product - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Excellent product - Positive: 10, Neutral: 0, Negative: 0
#   Aspect: My issue - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Only usb port - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Android auto - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: My car - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: My new mobile - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: C - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: C cable - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Original cable - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Order - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Wirelss adapter - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: This little converter - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: My 5k - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: No one - Positive: 0, Neutral: 0, Negative: 3
#   Aspect: E commerce platform - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: This one approx rs - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Mac book air - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Transfers data - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Best product - Positive: 7, Neutral: 0, Negative: 0
#   Aspect: Finish - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: A female - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: C male - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: 3.2 port - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Its working fine - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: No speed - Positive: 0, Neutral: 0, Negative: 1
#   Aspect: 1000mbps - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Sandisk 1500 mbps ssd - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: This test - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Fast & smooth data transfer - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Portronics - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Few indian brands - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: No false numbers - Positive: 0, Neutral: 0, Negative: 3
#   Aspect: Them - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Their products - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Eternity - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: ♥ - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Time - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Excellent condition - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: A sturdy build - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A premium finish - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Durability - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Data transfer speeds - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Any interruptions - Positive: 0, Neutral: 0, Negative: 1
#   Aspect: File transfers - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Functionality - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Excellent compact and sturdy product - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: My samsung 2tb ext - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Hdd - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: (st2000lm003 - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: My asus - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Laptop type c port - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Max speed - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: 65 mb/s - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Avg speed - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: 30mb/s - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Its hdd - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: My sandisk cruzer glide - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: 3.0 64 gb pen drive - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: 51 mb/s - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: 23 mb/s.
# these - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Initial testing - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Ssd - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Any second thought - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The quality product - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Its length - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Type c port - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The length - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: My system - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The performance - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: No delay - Positive: 0, Neutral: 0, Negative: 1
#   Aspect: Ilof - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Good build quality - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: Good read - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Trnsfering files - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Printer - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Separate apps - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: My usage - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A small lightweight, portable and great product - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Good and reliable product - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: Nice product - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: Ecellent product - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: My requirements - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: No problems - Positive: 0, Neutral: 0, Negative: 4
#   Aspect: Its job - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: All its good - Positive: 10, Neutral: 0, Negative: 0
#   Aspect: Value - Positive: 13, Neutral: 0, Negative: 0
#   Aspect: Great
# good quality - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Good item - Positive: 10, Neutral: 0, Negative: 0
#   Aspect: Very useful product - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: A port connectivity - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Usb c port - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Built quality - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Data transfer - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Bulid quality - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Maine jis kaam ke liye - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Ise - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Liya - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Tha - Positive: 0, Neutral: 7, Negative: 0
#   Aspect: Ye - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: One usb hub - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: A very well built and good quality otg - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: Adapter - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Its intended purpose - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: Apple carplay - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Good product
# works - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: The job - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Office - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Very good quality product - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: Great good quality - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: This otg work - Positive: 0, Neutral: 8, Negative: 0
#   Aspect: 20 support - Positive: 5, Neutral: 0, Negative: 0
#   Aspect: So full speed - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Quality good function works - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: Its very useful product - Positive: 6, Neutral: 0, Negative: 0
#   Aspect: Its jobquality - Positive: 0, Neutral: 9, Negative: 0
#   Aspect: Faster build quality - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: These otg good product - Positive: 3, Neutral: 0, Negative: 0
#   Aspect: This  type - Positive: 0, Neutral: 6, Negative: 0
#   Aspect: Typec - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: 109 build quality - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: Fast  smooth data transfer - Positive: 0, Neutral: 4, Negative: 0
#   Aspect: A - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Nice easily fit looks - Positive: 2, Neutral: 0, Negative: 0
#   Aspect: A jabra - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: A very well built and good quality - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Sd card - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: My mobile - Positive: 0, Neutral: 3, Negative: 0
#   Aspect: Nice overall value - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Compact small looks - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: My samsung 2tb - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Us - Positive: 0, Neutral: 5, Negative: 0
#   Aspect: The build - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: The - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: A fantastic - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: E - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: My - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Type c - Positive: 0, Neutral: 2, Negative: 0
#   Aspect: Only one thing - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: 3  material quality - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Some time - Positive: 0, Neutral: 1, Negative: 0
#   Aspect: Easy to use and very useful product - Positive: 1, Neutral: 0, Negative: 0
#   Aspect: Macbook pro - Positive: 0, Neutral: 1, Negative: 0
# 'aspect_based_sentiment_results.csv'

# %%
import spacy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# Download necessary NLTK resources
nltk.download('vader_lexicon')
nltk.download('punkt')

# Load the spaCy model for aspect extraction (noun chunks)
nlp = spacy.load("en_core_web_sm")

# Function to extract aspects and descriptions from reviews
def apply_extraction(row, nlp):
    """
    This function extracts aspects and their corresponding descriptions from the review
    by applying 7 different rules of POS tagging.
    """
    prod_pronouns = ['it','this','they','these']
    review_body = row['Review']
    doc = nlp(review_body)

    # Initialize lists to store extracted pairs
    rule1_pairs = []
    rule2_pairs = []
    rule3_pairs = []
    rule4_pairs = []
    rule5_pairs = []
    rule6_pairs = []
    rule7_pairs = []

    # Rule 1: Adjective Modifier (AMOD)
    for token in doc:
        A = "999999"
        M = "999999"
        if token.dep_ == "amod" and not token.is_stop:
            M = token.text
            A = token.head.text

            # Add adverbial modifier of adjective (e.g. 'most comfortable headphones')
            M_children = token.children
            for child_m in M_children:
                if(child_m.dep_ == "advmod"):
                    M_hash = child_m.text
                    M = M_hash + " " + M
                    break

            # Negation in adjective, the "no" keyword is a 'det' of the noun (e.g. no interesting characters)
            A_children = token.head.children
            for child_a in A_children:
                if(child_a.dep_ == "det" and child_a.text == 'no'):
                    neg_prefix = 'not'
                    M = neg_prefix + " " + M
                    break

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns:
                A = "product"
            dict1 = {"noun": A, "adj": M, "rule": 1}
            rule1_pairs.append(dict1)

    # Rule 2: Direct Object (DOBJ)
    for token in doc:
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in token.children:
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text

            if((child.dep_ == "dobj" and child.pos_ == "ADJ") and not child.is_stop):
                M = child.text

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns:
                A = "product"
            dict2 = {"noun": A, "adj": M, "rule": 2}
            rule2_pairs.append(dict2)

    # Rule 3: Adjectival Complement (ACOMP)
    for token in doc:
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in token.children:
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text

            if(child.dep_ == "acomp" and not child.is_stop):
                M = child.text

            if(child.dep_ == "aux" and child.tag_ == "MD"):
                neg_prefix = "not"
                add_neg_pfx = True

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns:
                A = "product"
            dict3 = {"noun": A, "adj": M, "rule": 3}
            rule3_pairs.append(dict3)

    # Rule 4: Passive Verb (nsubjpass)
    for token in doc:
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in token.children:
            if((child.dep_ == "nsubjpass" or child.dep_ == "nsubj") and not child.is_stop):
                A = child.text

            if(child.dep_ == "advmod" and not child.is_stop):
                M = child.text

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns:
                A = "product"
            dict4 = {"noun": A, "adj": M, "rule": 4}
            rule4_pairs.append(dict4)

    # Rule 5: Complement of Copular Verb (COP)
    for token in doc:
        A = "999999"
        buf_var = "999999"
        for child in token.children:
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text

            if(child.dep_ == "cop" and not child.is_stop):
                buf_var = child.text

        if(A != "999999" and buf_var != "999999"):
            if A in prod_pronouns:
                A = "product"
            dict5 = {"noun": A, "adj": token.text, "rule": 5}
            rule5_pairs.append(dict5)

    # Rule 6: Interjections (INTJ)
    for token in doc:
        A = "999999"
        M = "999999"
        if(token.pos_ == "INTJ" and not token.is_stop):
            for child in token.children:
                if(child.dep_ == "nsubj" and not child.is_stop):
                    A = child.text
                    M = token.text

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns:
                A = "product"
            dict6 = {"noun": A, "adj": M, "rule": 6}
            rule6_pairs.append(dict6)

    # Rule 7: Attributes (ATTR)
    for token in doc:
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in token.children:
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text

            if((child.dep_ == "attr") and not child.is_stop):
                M = child.text

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns:
                A = "product"
            dict7 = {"noun": A, "adj": M, "rule": 7}
            rule7_pairs.append(dict7)

    aspects = rule1_pairs + rule2_pairs + rule3_pairs + rule4_pairs + rule5_pairs + rule6_pairs + rule7_pairs
    dic = {"aspect_pairs": aspects}
    return dic
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Function to apply the aspect extraction to all reviews in the dataset
def extract_aspects(reviews, nlp):
    """
    Applying the aspect extraction function and returning a dictionary with
    key = Aspect & value = Description
    """
    print("Entering Apply function!")
    # Applying the extraction function to each row in the dataset
    # Create a temporary DataFrame with a 'Review' column
    temp_df = pd.DataFrame({'Review': reviews})
    aspect_list = temp_df.apply(lambda row: apply_extraction(row, nlp), axis=1)
    return aspect_list

# %%
# Load your dataset (replace with the actual path to your CSV file)
reviews_file_path = "/content/updated_amazon_reviews.csv"  # Update this path
reviews_df = pd.read_csv(reviews_file_path)


# Combine all review columns into a single text for each product
reviews_columns = [f'review{i}' for i in range(1, 501)]  # Assuming columns are named review1, review2, ..., review500
reviews_df['combined_reviews'] = reviews_df[reviews_columns].apply(lambda row: ' '.join(row.astype(str)), axis=1)


# Apply aspect extraction on the combined reviews column
aspect_extraction_results = extract_aspects(reviews_df['combined_reviews'], nlp)
# Convert results into a DataFrame for better visualization

aspect_extraction_df = pd.DataFrame(aspect_extraction_results)

# Save the result to a CSV file
output_file_path = 'extracted_aspects.csv'
aspect_extraction_df.to_csv(output_file_path, index=False)

output_file_path  # Return the path for downloading
# Out:
# Entering Apply function!
# 'extracted_aspects.csv'

# %%
def add_data(data, aspect_list):
    """
    This function adds aspect and the description to the dataframe such that if one review has multiple aspects,
    then the reviews are repeated such that each row consists of a single aspect and description.
    If no aspect is found, 'neutral' is assigned.
    """

    rev_ = []  # List containing reviews
    aspects_ = []  # List containing aspects
    description_ = []  # List containing descriptions

    for i, j in enumerate(aspect_list):
        length = len(list(j.values())[0])
        if length != 0:
            # Access the review using the index 'i' directly
            rev_a = [data.iloc[i] for k in range(len(list(j.values())[0]))]
            aspects_a = [list(j.values())[0][h]["noun"] for h in range(length)]
            descrip_a = [list(j.values())[0][h]["adj"] for h in range(length)]

            rev_.extend(rev_a)
            aspects_.extend(aspects_a)
            description_.extend(descrip_a)

        # If a review doesn't contain any aspect, add "neutral" for both the aspect & description column
        else:
            # Access the review using the index 'i' directly
            rev_.append(data.iloc[i])
            aspects_.append('neutral')
            description_.append('neutral')

    # Create a DataFrame from the lists (without the 'Date' column)
    data_ = pd.DataFrame({"Review": rev_, "Aspect": aspects_, "Description": description_})
    return data_

# %%
# Apply the add_data function
final_data = add_data(reviews_df['combined_reviews'], aspect_extraction_results)

# Save the result to a CSV file
output_file_path = '/content/final_aspect_data.csv'  # Update this path if needed
final_data.to_csv(output_file_path, index=False)

output_file_path  # Return the path for downloading
# Out:
# '/content/final_aspect_data.csv'

# %%
final_data
# Out:
#                                                   Review   Aspect  \
# 0      Boult newly launched Z20 truly wireless blueto...  earbuds
# 1      Boult newly launched Z20 truly wireless blueto...   weight
# 2      Boult newly launched Z20 truly wireless blueto...   weight
# 3      Boult newly launched Z20 truly wireless blueto...   weight
# 4      Boult newly launched Z20 truly wireless blueto...     time
# ...                                                  ...      ...
# 38373  I recently purchased the Portronics Type A to ...  quality
# 38374  I recently purchased the Portronics Type A to ...  quality
# 38375  I recently purchased the Portronics Type A to ...      OTG
# 38376  I recently purchased the Portronics Type A to ...  quality
# 38377  I recently purchased the Portronics Type A to ...  adapter
#
#           Description
# 0      truly wireless
# 1                good
# 2          very light
# 3             durable
# 4                long
# ...               ...
# 38373           Value
# 38374            item
# 38375         product
# 38376            item
# 38377          choice
#
# [38378 rows x 3 columns]

# %%
# Add a new column 'Usefulness' based on the 'overall_rating' column
reviews_df['Usefulness'] = reviews_df['overall_rating'].apply(lambda x: 'Useful' if x > 4.2 else 'Not Useful')

# Display the updated DataFrame with the 'Usefulness' column
reviews_df[['productID', 'overall_rating', 'Usefulness']].head()  # Display a sample of the result
# Out:
#     productID  overall_rating  Usefulness
# 0  B0DSG8SNXH             4.3      Useful
# 1  B0DFY3XCB6             4.0  Not Useful
# 2  B09TVVGXWS             4.1  Not Useful
# 3  B071Z8M4KX             4.1  Not Useful
# 4  B0C8JB3G5W             4.2  Not Useful

# %%
# Save the result to a CSV file
output_file_path = '/content/final_amazon_ground_truth_dataa.csv'  # Update this path if needed
reviews_df[['productID', 'overall_rating', 'Usefulness']].to_csv(output_file_path, index=False)
